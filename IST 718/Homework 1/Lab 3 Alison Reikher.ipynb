# %%
import pandas as pd

# %%
#loading in coach data
couches = pd.read_csv('Coaches9.csv')

# %%
couches
# Out:
#                     School Conference              Coach  SchoolPay  TotalPay  \
# 0                Air Force   Mt. West       Troy Calhoun     885000    885000
# 1                    Akron        MAC       Terry Bowden     411000    412500
# 2                  Alabama        SEC         Nick Saban    8307000   8307000
# 3    Alabama at Birmingham      C-USA         Bill Clark     900000    900000
# 4        Appalachian State   Sun Belt  Scott Satterfield     712500    712500
# ..                     ...        ...                ...        ...       ...
# 124          West Virginia     Big 12     Dana Holgorsen    3605000   3617500
# 125       Western Kentucky      C-USA   Mike Sanford Jr.     800000    805850
# 126       Western Michigan        MAC         Tim Lester     800000    800000
# 127              Wisconsin    Big Ten        Paul Chryst    3750000   3750000
# 128                Wyoming   Mt. West         Craig Bohl    1412000   1412000
#
# ...

# %%
#loading in graduation rates
gradRate = pd.read_csv('Graduation Rate.csv')

# %%
gradRate
# Out:
#                     School  GSR   FGR
# 0                Air Force   89   NaN
# 1                    Akron   79  76.0
# 2                  Alabama   89  65.0
# 3    Alabama at Birmingham   69  42.0
# 4        Appalachian State   78  60.0
# ..                     ...  ...   ...
# 124          West Virginia   74  60.0
# 125       Western Kentucky   74  57.0
# 126       Western Michigan   74  40.0
# 127              Wisconsin   90  81.0
# 128                Wyoming   87  52.0
#
# [129 rows x 3 columns]

# %%
#loading in stadium size
stadSize = pd.read_csv('Stadium Size.csv')

# %%
stadSize
# Out:
#                     School  Stadium Size
# 0                Air Force         46692
# 1                    Akron         30000
# 2                  Alabama        100077
# 3    Alabama at Birmingham         71594
# 4        Appalachian State         30000
# ..                     ...           ...
# 124          West Virginia         60000
# 125       Western Kentucky         22113
# 126       Western Michigan         30200
# 127              Wisconsin         80321
# 128                Wyoming         29181
#
# [129 rows x 2 columns]

# %%
#load in WL record
recordWL = pd.read_csv('Win Loss Record.csv')

# %%
recordWL
# Out:
#                     School  Wins  Loses
# 0                Air Force   414    335
# 1                    Akron   526    573
# 2                  Alabama   942    333
# 3    Alabama at Birmingham   153    169
# 4        Appalachian State   649    343
# ..                     ...   ...    ...
# 124          West Virginia   767    515
# 125       Western Kentucky   598    416
# 126       Western Michigan   588    466
# 127              Wisconsin   728    506
# 128                Wyoming   549    589
#
# [129 rows x 3 columns]

# %%
#combine all the dataframes into one dataframe
data = pd.concat([couches, gradRate, stadSize, recordWL], axis=1)

# %%
data
# Out:
#                     School Conference              Coach  SchoolPay  TotalPay  \
# 0                Air Force   Mt. West       Troy Calhoun     885000    885000
# 1                    Akron        MAC       Terry Bowden     411000    412500
# 2                  Alabama        SEC         Nick Saban    8307000   8307000
# 3    Alabama at Birmingham      C-USA         Bill Clark     900000    900000
# 4        Appalachian State   Sun Belt  Scott Satterfield     712500    712500
# ..                     ...        ...                ...        ...       ...
# 124          West Virginia     Big 12     Dana Holgorsen    3605000   3617500
# 125       Western Kentucky      C-USA   Mike Sanford Jr.     800000    805850
# 126       Western Michigan        MAC         Tim Lester     800000    800000
# 127              Wisconsin    Big Ten        Paul Chryst    3750000   3750000
# 128                Wyoming   Mt. West         Craig Bohl    1412000   1412000
#
# ...

# %%
#the column School gets repeated several times
data['School']
# Out:
#                     School                 School                 School  \
# 0                Air Force              Air Force              Air Force
# 1                    Akron                  Akron                  Akron
# 2                  Alabama                Alabama                Alabama
# 3    Alabama at Birmingham  Alabama at Birmingham  Alabama at Birmingham
# 4        Appalachian State      Appalachian State      Appalachian State
# ..                     ...                    ...                    ...
# 124          West Virginia          West Virginia          West Virginia
# 125       Western Kentucky       Western Kentucky       Western Kentucky
# 126       Western Michigan       Western Michigan       Western Michigan
# 127              Wisconsin              Wisconsin              Wisconsin
# 128                Wyoming                Wyoming                Wyoming
#
#                     School
# 0                Air Force
# 1                    Akron
# ...

# %%
data
# Out:
#                     School Conference              Coach  SchoolPay  TotalPay  \
# 0                Air Force   Mt. West       Troy Calhoun     885000    885000
# 1                    Akron        MAC       Terry Bowden     411000    412500
# 2                  Alabama        SEC         Nick Saban    8307000   8307000
# 3    Alabama at Birmingham      C-USA         Bill Clark     900000    900000
# 4        Appalachian State   Sun Belt  Scott Satterfield     712500    712500
# ..                     ...        ...                ...        ...       ...
# 124          West Virginia     Big 12     Dana Holgorsen    3605000   3617500
# 125       Western Kentucky      C-USA   Mike Sanford Jr.     800000    805850
# 126       Western Michigan        MAC         Tim Lester     800000    800000
# 127              Wisconsin    Big Ten        Paul Chryst    3750000   3750000
# 128                Wyoming   Mt. West         Craig Bohl    1412000   1412000
#
# ...

# %%
#all duplicate columns are dropped
data = data.T.drop_duplicates().T

# %%
data
# Out:
#                     School Conference              Coach SchoolPay TotalPay  \
# 0                Air Force   Mt. West       Troy Calhoun    885000   885000
# 1                    Akron        MAC       Terry Bowden    411000   412500
# 2                  Alabama        SEC         Nick Saban   8307000  8307000
# 3    Alabama at Birmingham      C-USA         Bill Clark    900000   900000
# 4        Appalachian State   Sun Belt  Scott Satterfield    712500   712500
# ..                     ...        ...                ...       ...      ...
# 124          West Virginia     Big 12     Dana Holgorsen   3605000  3617500
# 125       Western Kentucky      C-USA   Mike Sanford Jr.    800000   805850
# 126       Western Michigan        MAC         Tim Lester    800000   800000
# 127              Wisconsin    Big Ten        Paul Chryst   3750000  3750000
# 128                Wyoming   Mt. West         Craig Bohl   1412000  1412000
#
# ...

# %%
#convert column to numerical
#this process is done throughout the next several code blocks
data['SchoolPay'] = pd.to_numeric(data['SchoolPay'],errors='coerce')

# %%
data['SchoolPay'].describe()
# Out:
# count    1.290000e+02
# mean     2.422756e+06
# std      1.867777e+06
# min      3.900000e+05
# 25%      8.100000e+05
# 50%      1.900008e+06
# 75%      3.619775e+06
# max      8.307000e+06
# Name: SchoolPay, dtype: float64

# %%
data
# Out:
#                     School Conference              Coach  SchoolPay TotalPay  \
# 0                Air Force   Mt. West       Troy Calhoun     885000   885000
# 1                    Akron        MAC       Terry Bowden     411000   412500
# 2                  Alabama        SEC         Nick Saban    8307000  8307000
# 3    Alabama at Birmingham      C-USA         Bill Clark     900000   900000
# 4        Appalachian State   Sun Belt  Scott Satterfield     712500   712500
# ..                     ...        ...                ...        ...      ...
# 124          West Virginia     Big 12     Dana Holgorsen    3605000  3617500
# 125       Western Kentucky      C-USA   Mike Sanford Jr.     800000   805850
# 126       Western Michigan        MAC         Tim Lester     800000   800000
# 127              Wisconsin    Big Ten        Paul Chryst    3750000  3750000
# 128                Wyoming   Mt. West         Craig Bohl    1412000  1412000
#
# ...

# %%
data['TotalPay'] = pd.to_numeric(data['TotalPay'],errors='coerce')

# %%
data['TotalPay'].describe()
# Out:
# count    1.290000e+02
# mean     2.429306e+06
# std      1.872003e+06
# min      3.900000e+05
# 25%      8.100000e+05
# 50%      2.000000e+06
# 75%      3.619775e+06
# max      8.307000e+06
# Name: TotalPay, dtype: float64

# %%
data['Bonus'] = pd.to_numeric(data['Bonus'],errors='coerce')

# %%
data['Bonus'].describe()
# Out:
# count    1.290000e+02
# mean     8.648632e+05
# std      6.668935e+05
# min      0.000000e+00
# 25%      3.465000e+05
# 50%      7.416650e+05
# 75%      1.150000e+06
# max      3.100000e+06
# Name: Bonus, dtype: float64

# %%
data['BonusPaid'] = pd.to_numeric(data['BonusPaid'],errors='coerce')

# %%
data['BonusPaid'].describe()
# Out:
# count    1.290000e+02
# mean     1.020011e+05
# std      2.088806e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      2.000000e+04
# 75%      1.000000e+05
# max      1.350000e+06
# Name: BonusPaid, dtype: float64

# %%
data['AssistantPay'] = pd.to_numeric(data['AssistantPay'],errors='coerce')

# %%
data['AssistantPay'].describe()
# Out:
# count    129.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: AssistantPay, dtype: float64

# %%
data['Buyout'] = pd.to_numeric(data['Buyout'],errors='coerce')

# %%
data['Buyout'].describe()
# Out:
# count    1.290000e+02
# mean     7.559259e+06
# std      9.847946e+06
# min      0.000000e+00
# 25%      1.150000e+06
# 50%      3.847500e+06
# 75%      1.000000e+07
# max      6.812500e+07
# Name: Buyout, dtype: float64

# %%
data['GSR'] = pd.to_numeric(data['GSR'],errors='coerce')

# %%
data['GSR'].describe()
# Out:
# count    129.000000
# mean      80.945736
# std        8.743131
# min       58.000000
# 25%       74.000000
# 50%       82.000000
# 75%       88.000000
# max       97.000000
# Name: GSR, dtype: float64

# %%
data['FGR'] = pd.to_numeric(data['FGR'],errors='coerce')

# %%
data['FGR'].describe()
# Out:
# count    126.000000
# mean      62.888889
# std       11.101872
# min       28.000000
# 25%       56.000000
# 50%       62.500000
# 75%       69.000000
# max       94.000000
# Name: FGR, dtype: float64

# %%
data['Stadium Size'] = pd.to_numeric(data['Stadium Size'],errors='coerce')

# %%
data['Stadium Size'].describe()
# Out:
# count       129.000000
# mean      50907.775194
# std       23764.964955
# min        5400.000000
# 25%       30406.000000
# 50%       49250.000000
# 75%       64038.000000
# max      107601.000000
# Name: Stadium Size, dtype: float64

# %%
data['Wins'] = pd.to_numeric(data['Wins'],errors='coerce')

# %%
data['Wins'].describe()
# Out:
# count    129.000000
# mean     568.922481
# std      210.180637
# min       15.000000
# 25%      500.000000
# 50%      595.000000
# 75%      694.000000
# max      976.000000
# Name: Wins, dtype: float64

# %%
data['Loses'] = pd.to_numeric(data['Loses'],errors='coerce')

# %%
data['Loses'].describe()
# Out:
# count    129.000000
# mean     462.108527
# std      156.578567
# min       12.000000
# 25%      408.000000
# 50%      491.000000
# 75%      570.000000
# max      696.000000
# Name: Loses, dtype: float64

# %%
#final descriptive statisics of all the numerical data
data.describe()
# Out:
#           SchoolPay      TotalPay         Bonus     BonusPaid  AssistantPay  \
# count  1.290000e+02  1.290000e+02  1.290000e+02  1.290000e+02         129.0
# mean   2.422756e+06  2.429306e+06  8.648632e+05  1.020011e+05           0.0
# std    1.867777e+06  1.872003e+06  6.668935e+05  2.088806e+05           0.0
# min    3.900000e+05  3.900000e+05  0.000000e+00  0.000000e+00           0.0
# 25%    8.100000e+05  8.100000e+05  3.465000e+05  0.000000e+00           0.0
# 50%    1.900008e+06  2.000000e+06  7.416650e+05  2.000000e+04           0.0
# 75%    3.619775e+06  3.619775e+06  1.150000e+06  1.000000e+05           0.0
# max    8.307000e+06  8.307000e+06  3.100000e+06  1.350000e+06           0.0
#
#              Buyout         GSR         FGR   Stadium Size        Wins  \
# count  1.290000e+02  129.000000  126.000000     129.000000  129.000000
# mean   7.559259e+06   80.945736   62.888889   50907.775194  568.922481
# ...

# %%
#rename the column Stadium size
data.rename(columns = {'Stadium Size':'StadiumSize'}, inplace = True)

# %%
import matplotlib.pyplot as plt

# %%
#scatter plot of wins to loses ratio
#shows a slight linear relationship at first but then tappers off
plt.plot(data['Wins'], data['Loses'], 'o')

# %%
#scatter plot of total pay to wins
#appears to be a linear relationship
plt.plot(data['TotalPay'], data['Wins'], 'o')

# %%
#scatter plot of total pay to graduation rate
#no clear relationship
plt.plot(data['TotalPay'], data['GSR'], 'o')

# %%
#scatter plot of total pay to federal graduation rate
#no clear relationship
plt.plot(data['TotalPay'], data['FGR'], 'o')

# %%
#scatter plot of total pay to stadium size
#clear linear relationship
plt.plot(data['TotalPay'], data['StadiumSize'], 'o')

# %%
#scatter plot of total pay to loses
#no clear relationship
plt.plot(data['TotalPay'], data['Loses'], 'o')

# %%
#barchart of wins to total pay
plt.bar(data['Wins'], data['TotalPay'])
# Out:
# <BarContainer object of 129 artists>

# %%
#scatterplot of wins to loses but the color cordinates with total pay
plt.scatter('Wins', 'Loses', c='TotalPay', data=data)
plt.xlabel('entry Wins')
plt.ylabel('entry Loses')
# Out:
# Text(0, 0.5, 'entry Loses')

# %%
#scatter plot of wins to stadium size bu the color correlates to total pay
plt.scatter('Wins', 'StadiumSize', c='TotalPay', data=data)
plt.xlabel('entry Wins')
plt.ylabel('entry Stadium Size')
# Out:
# Text(0, 0.5, 'entry Stadium Size')

# %%
import seaborn as sns
#box plot of total pay by conference
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.boxplot(x="Conference", y="TotalPay", data=data, color = "gray");
plt.show()

# %%
#This block of code was added because of issues with importing the statsmodels
#This is what was suggested on the internet and it works
import  scipy.signal.signaltools

def _centered(arr, newsize):
    # Return the center newsize portion of the array.
    newsize = np.asarray(newsize)
    currsize = np.array(arr.shape)
    startind = (currsize - newsize) // 2
    endind = startind + newsize
    myslice = [slice(startind[k], endind[k]) for k in range(len(endind))]
    return arr[tuple(myslice)]

scipy.signal.signaltools._centered = _centered

# %%
from scipy.stats import uniform  # for training-and-test split
import statsmodels.api as sm  # statistical models (including regression)
import statsmodels.formula.api as smf  # R-like model specification

# %%
import numpy as np  # arrays and math functions
# employ training-and-test regimen for model validation
np.random.seed(1234)
data['runiform'] = uniform.rvs(loc = 0, scale = 1, size = len(data))
data_train = data[data['runiform'] >= 0.33]
data_test = data[data['runiform'] < 0.33]
# check training data frame
print('\ncouch_train data frame (rows, columns): ',data_train.shape)
print(data_train.head())
# check test data frame
print('\ncouch_test data frame (rows, columns): ',data_test.shape)
print(data_test.head())
# Out:
# couch_train data frame (rows, columns):  (92, 15)
#                   School Conference              Coach  SchoolPay  TotalPay  \
# 1                  Akron        MAC       Terry Bowden     411000    412500
# 2                Alabama        SEC         Nick Saban    8307000   8307000
# 3  Alabama at Birmingham      C-USA         Bill Clark     900000    900000
# 4      Appalachian State   Sun Belt  Scott Satterfield     712500    712500
# 7               Arkansas        SEC        Chad Morris    3500000   3500000
#
#      Bonus  BonusPaid  AssistantPay    Buyout  GSR   FGR  StadiumSize  Wins  \
# 1   225000      50000             0    688500   79  76.0        30000   526
# 2  1100000     500000             0  33600000   89  65.0       100077   942
# 3   950000     165471             0   3847500   69  42.0        71594   153
# 4   295000     145000             0   2160417   78  60.0        30000   649
# 7  1000000          0             0  12500000   84  57.0        76212   729
#
# ...

# %%
# MODEL

# specify a simple model with TotalPay as a function of Wins
my_model_simple1 = str('TotalPay ~ Wins')

# fit the model to the training set
train_model_fit1 = smf.ols(my_model_simple1, data = data_train).fit()
# summary of model fit to the training set
print(train_model_fit1.summary())
# training set predictions from the model fit to the training set
data_train['predict_wins'] = train_model_fit1.fittedvalues

# test set predictions from the model fit to the training set
data_test['predict_wins'] = train_model_fit1.predict(data_test)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               TotalPay   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     54.61
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):           7.23e-11
# Time:                        14:57:19   Log-Likelihood:                -1438.7
# No. Observations:                  92   AIC:                             2881.
# Df Residuals:                      90   BIC:                             2886.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.542e+05   4.52e+05     -1.447      0.151   -1.55e+06    2.44e+05
# ...

# %%
print('\nProportion of Test Set Variance Accounted for: ',\
    round(np.power(data_test['TotalPay'].corr(data_test['predict_wins']),2),3))

my_model_fit = smf.ols(my_model, data = data).fit()
print(my_model_fit.summary())

print('\nEstimated Effect of Wins and Stadium Size on Total Pay: ',\
    round(my_model_fit.params[2],0))
# Out:
# Proportion of Test Set Variance Accounted for:  0.387
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-3906b83d4a1f> in <module>
#       2     round(np.power(data_test['TotalPay'].corr(data_test['predict_wins']),2),3))
#       3
# ----> 4 my_model_fit = smf.ols(my_model, data = data).fit()
#       5 print(my_model_fit.summary())
#       6
#
# NameError: name 'my_model' is not defined

# %%
my_model2 = str('TotalPay ~ Wins + StadiumSize')

# fit the model to the training set
train_model_fit2 = smf.ols(my_model2, data = data_train).fit()
# summary of model fit to the training set
print(train_model_fit2.summary())
# training set predictions from the model fit to the training set
data_train['predict_pay_win_size'] = train_model_fit2.fittedvalues

# test set predictions from the model fit to the training set
data_test['predict_pay_win_size'] = train_model_fit2.predict(data_test)

# %%
print('\nProportion of Test Set Variance Accounted for: ',\
    round(np.power(data_test['TotalPay'].corr(data_test['predict_pay_win_size']),2),3))


my_model_fit2 = smf.ols(my_model2, data = data).fit()
print(my_model_fit2.summary())

print('\nEstimated Effect of Wins and Stadium Size on Total Pay: ',\
    round(my_model_fit2.params[2],0))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predict_pay_win_size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-71ac13573c51> in <module>
# ...

# %%
my_model3 = str('TotalPay ~ + Wins + Buyout + StadiumSize')

# fit the model to the training set
train_model_fit3 = smf.ols(my_model3, data = data_train).fit()
# summary of model fit to the training set
print(train_model_fit3.summary())
# training set predictions from the model fit to the training set
data_train['predict_pay_all'] = train_model_fit3.fittedvalues

# test set predictions from the model fit to the training set
data_test['predict_pay_all'] = train_model_fit3.predict(data_test)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               TotalPay   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     115.8
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):           1.87e-30
# Time:                        14:57:20   Log-Likelihood:                -1386.9
# No. Observations:                  92   AIC:                             2782.
# Df Residuals:                      88   BIC:                             2792.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -3.791e+05   3.02e+05     -1.255      0.213    -9.8e+05    2.21e+05
# ...

# %%
print('\nProportion of Test Set Variance Accounted for: ',\
    round(np.power(data_test['TotalPay'].corr(data_test['predict_pay_all']),2),3))

my_model_fit3 = smf.ols(my_model3, data = data).fit()
print(my_model_fit3.summary())

print('\nEstimated Effect of Everything on Total Pay: ',\
    round(my_model_fit3.params[0],0))
# Out:
# Proportion of Test Set Variance Accounted for:  0.734
#                             OLS Regression Results
# ...
# Dep. Variable:               TotalPay   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     144.9
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):           1.62e-40
# Time:                        14:57:20   Log-Likelihood:                -1948.9
# No. Observations:                 129   AIC:                             3906.
# Df Residuals:                     125   BIC:                             3917.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
#creates colorful correlation matrix
corr = data.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()
# Out:
# <ipython-input-61-b2494608f2e9>:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr, dtype=np.bool)

# %%
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression

#find relationship between total pay and graduation rate
dataX = data[['TotalPay']]
dataY = data[['GSR']]

# %%
# Creates a basic linear model
model_new1 = LinearRegression().fit(dataX, dataY)
model_new1.score(dataX, dataY)
# Out:
# 0.034709741825771356

# %%
#finds relationship between total pay and wins
data2X = data[['TotalPay']]
data2Y = data[['Wins']]
model_new2 = LinearRegression().fit(data2X, data2Y)
model_new2.score(data2X, data2Y)
# Out:
# 0.3809350548347794

# %%
#finds relationship between total pay and stadium size
data3X = data[['TotalPay']]
data3Y = data[['StadiumSize']]
model_new3 = LinearRegression().fit(data3X, data3Y)
model_new3.score(data3X, data3Y)
# Out:
# 0.59900376345568

# %%
#finds relationship between total pay and buyout
data4X = data[['TotalPay']]
data4Y = data[['Buyout']]
model_new4 = LinearRegression().fit(data4X, data4Y)
model_new4.score(data4X, data4Y)
# Out:
# 0.6585450996118538

# %%
#creates dataframe with teams in the AAC or Big East
AAC = data.loc[data['Conference'] == 'AAC']

# %%
AAC
# Out:
#                  School Conference               Coach  SchoolPay  TotalPay  \
# 19      Central Florida        AAC         Josh Heupel    1700000   1700000
# 22           Cincinnati        AAC        Luke Fickell    2000000   2000000
# 27          Connecticut        AAC        Randy Edsall    1100000   1100000
# 29        East Carolina        AAC  Scottie Montgomery    1102500   1102500
# 41              Houston        AAC    Major Applewhite    1750000   1750000
# 59              Memphis        AAC        Mike Norvell    2600000   2600000
# 69                 Navy        AAC     Ken Niumatalolo    2163000   2163000
# 97        South Florida        AAC      Charlie Strong    1000000   1000000
# 99   Southern Methodist        AAC         Sonny Dykes    4000000   4000000
# 113              Tulane        AAC        Willie Fritz    1629000   1629000
# 114               Tulsa        AAC   Philip Montgomery    1518177   1518177
#
# ...

# %%
#descriptive statics for Big East
AAC.describe()
# Out:
#           SchoolPay      TotalPay          Bonus      BonusPaid  AssistantPay  \
# count  1.100000e+01  1.100000e+01      11.000000      11.000000          11.0
# mean   1.869334e+06  1.869334e+06  548393.000000   36727.272727           0.0
# std    8.565373e+05  8.565373e+05  278725.320054   64286.998544           0.0
# min    1.000000e+06  1.000000e+06  158000.000000       0.000000           0.0
# 25%    1.310338e+06  1.310338e+06  253000.000000       0.000000           0.0
# 50%    1.700000e+06  1.700000e+06  650000.000000       0.000000           0.0
# 75%    2.081500e+06  2.081500e+06  778750.000000   45000.000000           0.0
# max    4.000000e+06  4.000000e+06  850000.000000  185000.000000           0.0
#
#              Buyout       GSR        FGR   StadiumSize        Wins  \
# count  1.100000e+01  11.00000  10.000000     11.000000   11.000000
# mean   3.077937e+06  81.00000  66.800000  44979.909091  458.454545
# ...

# %%
3.077937e+06
# Out:
# 3077937.0

# %%
#creates dataframe with just the Big Ten conference teams
bigTen = data.loc[data['Conference'] == 'Big Ten']

# %%
bigTen
# Out:
#              School Conference           Coach  SchoolPay  TotalPay    Bonus  \
# 42         Illinois    Big Ten     Lovie Smith    5000000   5000000  1000000
# 43          Indiana    Big Ten       Tom Allen    1830000   1830000  1441668
# 44             Iowa    Big Ten    Kirk Ferentz    4700000   4700000  2875000
# 57         Maryland    Big Ten       DJ Durkin    2512000   2512000   625000
# 62         Michigan    Big Ten    Jim Harbaugh    7504000   7504000  1325000
# 63   Michigan State    Big Ten   Mark Dantonio    4390417   4390417   650000
# 65        Minnesota    Big Ten      P.J. Fleck    3550000   3550000   900000
# 70         Nebraska    Big Ten     Scott Frost    5000000   5000000   950000
# 79     Northwestern    Big Ten  Pat Fitzgerald    3619775   3619775   960000
# 82       Ohio State    Big Ten     Urban Meyer    7600000   7600000   775000
# 88       Penn State    Big Ten  James Franklin    4800000   4800000  1000000
# ...

# %%
#descriptive statistics for big ten
bigTen.describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  1.400000e+01  1.400000e+01  1.400000e+01      14.000000          14.0
# mean   4.304014e+06  4.304014e+06  1.075119e+06  149642.857143           0.0
# std    1.706078e+06  1.706078e+06  5.974864e+05  179448.560079           0.0
# min    1.830000e+06  1.830000e+06  3.000000e+05       0.000000           0.0
# 25%    3.567444e+06  3.567444e+06  8.062500e+05       0.000000           0.0
# 50%    4.095208e+06  4.095208e+06  9.600000e+05   87500.000000           0.0
# 75%    4.950000e+06  4.950000e+06  1.217500e+06  262500.000000           0.0
# max    7.600000e+06  7.600000e+06  2.875000e+06  600000.000000           0.0
#
#              Buyout        GSR        FGR    StadiumSize        Wins  \
# count  1.400000e+01  14.000000  14.000000      14.000000   14.000000
# mean   1.394635e+07  87.142857  70.571429   72495.071429  728.785714
# ...

# %%
#information for just Syracuse for reference
data.loc[data['School'] == 'Syracuse']
# Out:
#        School Conference        Coach  SchoolPay  TotalPay    Bonus  \
# 102  Syracuse        ACC  Dino Babers    2401206   2401206  1600000
#
#      BonusPaid  AssistantPay   Buyout  GSR   FGR  StadiumSize  Wins  Loses  \
# 102          0             0  6500000   88  76.0        49250   730    564
#
#      runiform
# 102  0.796867

# %%
data.loc[data['Conference'] == 'ACC'].describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  1.400000e+01  1.400000e+01  1.400000e+01      14.000000          14.0
# mean   3.409629e+06  3.433797e+06  1.259996e+06  147851.214286           0.0
# std    1.165548e+06  1.229711e+06  7.507660e+05  254303.852926           0.0
# min    1.831580e+06  1.831580e+06  1.000000e+05       0.000000           0.0
# 25%    2.549446e+06  2.549446e+06  9.562500e+05       0.000000           0.0
# 50%    3.038868e+06  3.038868e+06  1.323334e+06   25000.000000           0.0
# 75%    3.995108e+06  3.995108e+06  1.474479e+06  187500.000000           0.0
# max    6.205000e+06  6.543350e+06  2.941939e+06  869917.000000           0.0
#
#              Buyout        GSR        FGR   StadiumSize        Wins  \
# count  1.400000e+01  14.000000  14.000000     14.000000   14.000000
# mean   1.109635e+07  83.285714  67.000000  58387.285714  655.357143
# std    9.932964e+06  11.013478  13.243286  14299.460987  100.012005
# ...

# %%
#finding averages for schools with the same graduation rate
data.loc[data['GSR'] == 88].describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  5.000000e+00  5.000000e+00  5.000000e+00       5.000000           5.0
# mean   2.937747e+06  3.005417e+06  8.200000e+05  259000.000000           0.0
# std    2.059013e+06  2.194350e+06  5.644134e+05  299215.641302           0.0
# min    9.325210e+05  9.325210e+05  1.500000e+05       0.000000           0.0
# 25%    1.650010e+06  1.650010e+06  4.750000e+05       0.000000           0.0
# 50%    2.401206e+06  2.401206e+06  7.500000e+05  145000.000000           0.0
# 75%    3.500000e+06  3.500000e+06  1.125000e+06  500000.000000           0.0
# max    6.205000e+06  6.543350e+06  1.600000e+06  650000.000000           0.0
#
#              Buyout   GSR        FGR  StadiumSize        Wins       Loses  \
# count  5.000000e+00   5.0   4.000000      5.00000    5.000000    5.000000
# mean   1.501514e+07  88.0  66.250000  48950.00000  650.000000  484.600000
# ...

# %%
#finding averages for schools with the same federal graduation rate
data.loc[data['FGR'] == 76].describe()
# Out:
#           SchoolPay      TotalPay         Bonus     BonusPaid  AssistantPay  \
# count  6.000000e+00  6.000000e+00  6.000000e+00      6.000000           6.0
# mean   1.709344e+06  1.709594e+06  6.480000e+05  29166.666667           0.0
# std    7.578553e+05  7.573414e+05  5.924846e+05  33229.003396           0.0
# min    4.110000e+05  4.125000e+05  1.000000e+05      0.000000           0.0
# 25%    1.532250e+06  1.532250e+06  1.747500e+05      0.000000           0.0
# 50%    1.714500e+06  1.714500e+06  5.625000e+05  25000.000000           0.0
# 75%    2.250904e+06  2.250904e+06  9.037500e+05  50000.000000           0.0
# max    2.514859e+06  2.514859e+06  1.600000e+06  75000.000000           0.0
#
#              Buyout       GSR   FGR   StadiumSize        Wins       Loses  \
# count  6.000000e+00   6.00000   6.0      6.000000    6.000000    6.000000
# mean   4.432833e+06  85.00000  76.0  41769.500000  615.833333  578.000000
# ...

# %%
#finding averages for schools with similar stadium sizes
data.loc[(data['StadiumSize'] < 50000) & (data['StadiumSize'] > 45000)].describe()
# Out:
#           SchoolPay      TotalPay         Bonus  BonusPaid  AssistantPay  \
# count  6.000000e+00  6.000000e+00  6.000000e+00        6.0           6.0
# mean   2.799100e+06  2.799100e+06  1.078805e+06        0.0           0.0
# std    1.665535e+06  1.665535e+06  8.354463e+05        0.0           0.0
# min    8.850000e+05  8.850000e+05  2.470000e+05        0.0           0.0
# 25%    1.300930e+06  1.300930e+06  5.743718e+05        0.0           0.0
# 50%    3.010490e+06  3.010490e+06  7.800000e+05        0.0           0.0
# 75%    3.990244e+06  3.990244e+06  1.440000e+06        0.0           0.0
# max    4.840717e+06  4.840717e+06  2.500000e+06        0.0           0.0
#
#              Buyout        GSR        FGR   StadiumSize        Wins  \
# count  6.000000e+00   6.000000   5.000000      6.000000    6.000000
# mean   5.133333e+06  87.666667  76.800000  47035.333333  574.000000
# std    6.989039e+06   9.201449  14.788509   1313.497113  114.736219
# ...

# %%
#finding averages for schools with similar win records
data.loc[(data['Wins'] < 750) & (data['Wins'] > 700)].describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  1.400000e+01  1.400000e+01  1.400000e+01      14.000000          14.0
# mean   3.042937e+06  3.042937e+06  9.281984e+05   91345.428571           0.0
# std    1.379173e+06  1.379173e+06  5.486010e+05  124757.578761           0.0
# min    5.248260e+05  5.248260e+05  1.500000e+05       0.000000           0.0
# 25%    2.444654e+06  2.444654e+06  5.990825e+05       0.000000           0.0
# 50%    3.038868e+06  3.038868e+06  9.125000e+05    6334.500000           0.0
# 75%    3.700000e+06  3.700000e+06  1.237500e+06  200000.000000           0.0
# max    6.070000e+06  6.070000e+06  2.150000e+06  297000.000000           0.0
#
#              Buyout        GSR        FGR   StadiumSize        Wins  \
# count  1.400000e+01  14.000000  12.000000     14.000000   14.000000
# mean   6.935298e+06  86.642857  65.666667  57252.428571  724.857143
# std    4.307020e+06   7.642061  12.665869  18562.848707   14.596402
# ...

# %%
#finding averages for schools with similar loss records
data.loc[(data['Loses'] < 575) & (data['Loses'] > 550)].describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  1.400000e+01  1.400000e+01  1.400000e+01      14.000000          14.0
# mean   2.230878e+06  2.230986e+06  8.865475e+05   93392.857143           0.0
# std    1.592132e+06  1.592000e+06  7.075900e+05  161940.181094           0.0
# min    4.110000e+05  4.125000e+05  1.450000e+05       0.000000           0.0
# 25%    8.625000e+05  8.625000e+05  5.012500e+05       0.000000           0.0
# 50%    1.950603e+06  1.950603e+06  7.533325e+05   52500.000000           0.0
# 75%    3.375000e+06  3.375000e+06  9.000000e+05   72500.000000           0.0
# max    5.000000e+06  5.000000e+06  2.875000e+06  600000.000000           0.0
#
#              Buyout        GSR        FGR   StadiumSize        Wins  \
# count  1.400000e+01  14.000000  13.000000     14.000000   14.000000
# mean   6.751574e+06  81.142857  64.230769  45478.142857  601.285714
# std    6.223840e+06   6.882052   8.257863  14689.645756  104.346633
# ...

# %%
#finding averages based on similar buyouts
data.loc[(data['Buyout'] > 6000000) & (data['Buyout'] < 7000000)].describe()
# Out:
#           SchoolPay      TotalPay         Bonus      BonusPaid  AssistantPay  \
# count  4.000000e+00  4.000000e+00  4.000000e+00       4.000000           4.0
# mean   1.783808e+06  1.784183e+06  8.065355e+05   85035.500000           0.0
# std    1.087798e+06  1.087347e+06  7.786556e+05  130312.873658           0.0
# min    8.015040e+05  8.030040e+05  1.261420e+05       0.000000           0.0
# 25%    8.997668e+05  9.001418e+05  1.440355e+05       0.000000           0.0
# 50%    1.666864e+06  1.666864e+06  7.500000e+05   32571.000000           0.0
# 75%    2.550904e+06  2.550904e+06  1.412500e+06  117606.500000           0.0
# max    3.000000e+06  3.000000e+06  1.600000e+06  275000.000000           0.0
#
#              Buyout       GSR        FGR   StadiumSize        Wins  \
# count  4.000000e+00   4.00000   3.000000      4.000000    4.000000
# mean   6.439694e+06  86.25000  65.000000  43792.250000  659.250000
# std    2.190685e+05   8.80814  10.535654  11536.758943   73.295634
# ...

# %%
#full correlation matrix
data.corr()
# Out:
#               SchoolPay  TotalPay     Bonus  BonusPaid  AssistantPay  \
# SchoolPay      1.000000  0.999697  0.437908   0.376420           NaN
# TotalPay       0.999697  1.000000  0.440715   0.377395           NaN
# Bonus          0.437908  0.440715  1.000000   0.314047           NaN
# BonusPaid      0.376420  0.377395  0.314047   1.000000           NaN
# AssistantPay        NaN       NaN       NaN        NaN           NaN
# Buyout         0.809079  0.811508  0.358079   0.388892           NaN
# GSR            0.187363  0.186306  0.045608  -0.037034           NaN
# FGR           -0.017785 -0.018995 -0.090572  -0.072888           NaN
# StadiumSize    0.773851  0.773953  0.368384   0.287237           NaN
# Wins           0.616686  0.617199  0.273038   0.245912           NaN
# Loses          0.109588  0.109753  0.131288   0.021142           NaN
# runiform      -0.023596 -0.026256  0.015831   0.003527           NaN
#
# ...
